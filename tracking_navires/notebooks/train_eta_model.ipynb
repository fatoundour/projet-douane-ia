# %% [markdown]
# # 📘 Entraînement du modèle ETA - Tracking des navires

# %%
# 1. Importation des bibliothèques
import sys, os
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import joblib
import matplotlib.pyplot as plt

# %%
# Ajout du chemin racine dans le module de chemin parcouru par python afin de trouver les modules à importer
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', '..')))

# %%
# 2. Chargement des données
from common_utils.loader import load_csv_with_dates
df = load_csv_with_dates('../data/ais_data.csv',["timestamp","eta_real"])
df.dropna
# Out:
#          mmsi           timestamp       lat       lon  speed  \
# 0   236111111 2025-07-01 08:00:00  14.29766 -17.49919   13.8
# 1   236111111 2025-07-01 08:10:00  14.31485 -17.48635   11.8
# 2   236111111 2025-07-01 08:20:00  14.32051 -17.48164   11.2
# 3   236111111 2025-07-01 08:30:00  14.33190 -17.46850   12.8
# 4   236111111 2025-07-01 08:40:00  14.34028 -17.45780   12.2
# 5   236111111 2025-07-01 08:50:00  14.35011 -17.44711   11.2
# 6   236111111 2025-07-01 09:00:00  14.36402 -17.43541   12.9
# 7   236111111 2025-07-01 09:10:00  14.37378 -17.42824   13.7
# 8   236111111 2025-07-01 09:20:00  14.37817 -17.42029   11.8
# 9   236111111 2025-07-01 09:30:00  14.38983 -17.41244   12.7
# 10  236222222 2025-07-01 08:00:00  14.30002 -17.50107   12.6
# 11  236222222 2025-07-01 08:10:00  14.31322 -17.48739   12.0
# 12  236222222 2025-07-01 08:20:00  14.32349 -17.47944   13.9
# 13  236222222 2025-07-01 08:30:00  14.33309 -17.46654   13.5
# ...

# %%
print(df.dtypes)
# Out:
# mmsi                  int64
# timestamp    datetime64[ns]
# lat                 float64
# lon                 float64
# speed               float64
# eta_real     datetime64[ns]
# dtype: object

# %%
# 3. Préparation des variables

# %%
# 4. Entraînement du modèle de prédiction ETA

# %%
# 5. Sauvegarde du modèle entraîné
